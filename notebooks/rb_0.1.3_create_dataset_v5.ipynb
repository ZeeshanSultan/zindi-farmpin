# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# # Create VI Dataset v5
#
# **Changes**
#
# * More VI Methods
# * Less stats - only median and std dev

# %%
import sys
sys.path.append('../')

import numpy as np
import pandas as pd

from tqdm import tqdm
from config import interim_data_dir, raw_data_dir

from src.utils import read_shapefile

dataset_version = "v5.2"

# %% [markdown]
# ## VI Methods

# %%
vi_methods = [
    'ndvi',
    'cvi',
    'evi',
    'arvi2',
    'arvi',
    'datt1',
    'atsavi',
    'maccioni',
    'gari',
    'gbndvi',
    'mnsi',
    'msbi',
    'band_2',
    'band_3',
    'band_4',
    'band_5',
    'band_6',
    'band_7',
    'band_8',
    'band_8a',
    'band_11',
    'band_12',
]




def calc_ndvi(bands_data):
    return (bands_data['B08'] - bands_data['B04'])/(bands_data['B08'] + bands_data['B04'])

def calc_cvi(bands_data):
    """
    (𝐵𝑎𝑛𝑑8 ∗ 𝐵𝑎𝑛𝑑4) / (𝐵𝑎𝑛𝑑3)^2
    """
    return (bands_data['B08'] * bands_data['B04']) / (bands_data['B03']**2)

def calc_datt1(bands_data):
    """
    𝐵𝑎𝑛𝑑8 − 𝐵𝑎𝑛𝑑5 / 𝐵𝑎𝑛𝑑8 − 𝐵𝑎𝑛𝑑4
    """
    return (bands_data['B08'] - bands_data['B05'])/(bands_data['B08'] - bands_data['B04'])

def calc_evi(bands_data):
    """
    2.5* (𝐵𝑎𝑛𝑑8 − 𝐵𝑎𝑛𝑑4) / (𝐵𝑎𝑛𝑑8 + 6 ∗ 𝐵𝑎𝑛𝑑4 − 7.5 ∗ 𝐵𝑎𝑛𝑑2 + 1)
    """
    return 2.5* (bands_data['B08'] - bands_data['B04']) / (bands_data['B08'] + 6*bands_data['B04'] - 7.5 * bands_data['B02'] + 1)

def calc_arvi2(bands_data):
    return -0.18 + 1.17 * calc_ndvi(bands_data)

def calc_atsavi(bands_data):
    """
    a ∗ (Band8 − a ∗ Band4 − b) / (Band8 + Band4 − ab + X(1 + 𝑎2))
    
    a = 1.22, b=0.03, X=0.08
    """
    
    a = 1.22
    b=0.03
    X=0.08
    
    return a * (bands_data['B08'] - a*bands_data['B04'] - b) /\
            (bands_data['B08'] + bands_data['B04'] - a*b + X * (1 + a**2))

def calc_maccioni(bands_data):
    """
    (𝐵𝑎𝑛𝑑7 − 𝐵𝑎𝑛𝑑5) / (𝐵𝑎𝑛𝑑7 − 𝐵𝑎𝑛𝑑4)
    """
    return (bands_data['B07'] - bands_data['B05']) / (bands_data['B07'] - bands_data['B04'])


def calc_arvi(bands_data):
    """
    (𝐵𝑎𝑛𝑑8 − (𝐵𝑎𝑛𝑑4 − 𝛾(𝐵𝑎𝑛𝑑2 −𝐵𝑎𝑛𝑑4)) / 
    (𝐵𝑎𝑛𝑑8 + (𝐵𝑎𝑛𝑑4 − 𝛾(𝐵𝑎𝑛𝑑2 −𝐵𝑎𝑛𝑑4))
    
    𝛾 = 1
    
    """
    nom = (bands_data['B08'] - (bands_data['B04'] - (bands_data['B02'] -bands_data['B04'])))
    denom = (bands_data['B08'] + (bands_data['B04'] - (bands_data['B02'] -bands_data['B04'])))
    
    return nom / denom

def calc_gari(bands_data):
    """
    𝐵𝑎𝑛𝑑8 − (𝐵𝑎𝑛𝑑3 − (𝐵𝑎𝑛𝑑2 − 𝐵𝑎𝑛𝑑4)) /
    𝐵𝑎𝑛𝑑8 − (𝐵𝑎𝑛𝑑3 + (𝐵𝑎𝑛𝑑2 − 𝐵𝑎𝑛𝑑4))
    
    """
    nom = (bands_data['B08'] - (bands_data['B03'] - (bands_data['B02'] -bands_data['B04'])))
    denom = (bands_data['B08'] + (bands_data['B03'] + (bands_data['B02'] -bands_data['B04'])))
    
    return nom / denom

def calc_gbndvi(bands_data):
    """
    𝐵𝑎𝑛𝑑8 − (𝐵𝑎𝑛𝑑3 + 𝐵𝑎𝑛𝑑2) /
    𝐵𝑎𝑛𝑑8 + (𝐵𝑎𝑛𝑑3 + 𝐵𝑎𝑛𝑑2)
    """
    
    nom = (bands_data['B08'] - (bands_data['B03'] + bands_data['B02']))
    denom = (bands_data['B08'] + (bands_data['B03'] + bands_data['B02']))
    
    return nom / denom
    
    
def calc_mnsi(bands_data):
    """
    0.404 ∗ Band3 + 0.039 ∗ Band4 − 0.505 ∗ Band6 + 0.762 ∗ Band8
    """
    
    return 0.404 * bands_data['B03'] + 0.039 * bands_data['B04'] - 0.505 * bands_data['B06'] + 0.762 * bands_data['B08']


def calc_msbi(bands_data):
    """
    0.406 ∗ Band3 + 0.600 ∗ Band4 + 0.645 ∗ Band6 + 0.243 ∗ Band8
    """
    
    return 0.406 * bands_data['B03'] + 0.6 * bands_data['B04']  + 0.645 * bands_data['B06'] + 0.762 * bands_data['B08']



# Just the bands
def calc_band_2(bands_data):
    return bands_data['B02']

def calc_band_3(bands_data):
    return bands_data['B03']

def calc_band_4(bands_data):
    return bands_data['B04']

def calc_band_5(bands_data):
    return bands_data['B05']

def calc_band_6(bands_data):
    return bands_data['B06']

def calc_band_7(bands_data):
    return bands_data['B07']

def calc_band_8(bands_data):
    return bands_data['B08']

def calc_band_8a(bands_data):
    return bands_data['B8A']

def calc_band_11(bands_data):
    return bands_data['B11']

def calc_band_12(bands_data):
    return bands_data['B12']

# %%
import time
from multiprocessing import Pool
from functools import partial

# Number of time stamps
N_ts = 11

# Number of bands
N_b = 10

VALID_AGG_METHODS = ['mean','median','min','max','std']


def load_for_id(farm_id, dataset, bands_subset=None):
    """
    Load all data for a farm
    
    Return:
    
    dictionary: {band: {date: ndarray}, {...}}
    """
    farm_dir = interim_data_dir / 'masks_resampled' / dataset / str(farm_id)

    dates = farm_dir.glob('*/')
    farm_data = {}
    
    for date_path in dates:
        
        date = date_path.stem

        bands = date_path.glob("*.npy")
        
        farm_data[date_path.stem] = {}
        
        for band_path in bands:
            band = band_path.stem
            
            if bands_subset and band in bands_subset:
                arr = np.load(band_path)
                farm_data[date][band] = arr
            else:
                arr = np.load(band_path)
                farm_data[date][band] = arr
        
    return farm_data

def agg_arr(arr, agg_method):
    """
    aggregate an array with a nan-aware numpy method
    """
    assert agg_method in VALID_AGG_METHODS
    return eval(f'np.nan{agg_method}')(arr.flatten())

def calc_vi_ts(farm_data, farm_id, agg_methods, which_vi='ndvi'):
    """
    Calculate vegetation index time series for a farm
    """
    vi_data = {}
    for date, bands_data in farm_data.items():
        # Get aggregated statistics of VI signals for this date
        vi_data[date] = [agg_arr(eval(f'calc_{which_vi}')(bands_data), agg_method) for agg_method in agg_methods]
        
    vi = pd.DataFrame.from_dict(vi_data, orient='index')
    vi.index = pd.to_datetime(vi.index)
    vi.index.name='time'
    vi.columns = [f'{which_vi}_{agg_method}' for agg_method in agg_methods]
    
    return pd.concat([vi], keys=[farm_id], names=['farm_id'])




def f(farm_id, dataset, bands_subset, agg_methods):
    farm_data = load_for_id(farm_id, dataset, bands_subset=bands_subset)

    vi_data = [calc_vi_ts(farm_data, farm_id, agg_methods, vi_method) for vi_method in vi_methods]

    vi_df = pd.concat(vi_data, axis=1)

    return vi_df

def create_features_dataset_multi(dataset='train', bands_subset=None, agg_methods=['mean','median'], limit_farms=None, add_bands=True):
    """
    A multi-processing solution
    
    """
    
    shp_df = read_shapefile(dataset)
    
    ids_list = shp_df.index.to_list()
    
    if limit_farms:
        ids_list = ids_list[:limit_farms]
        
    partials = partial(f, dataset=dataset, bands_subset=bands_subset, agg_methods=agg_methods)
        
    pool = Pool(processes=10)
    result = pool.map_async(partials, ids_list)
    
    i = 0
    t_start = time.time()
    while not result.ready():
        if i == 10:
            i=0
            e = int(time.time() - t_start)
            print('\n Elapsed: {:02d}:{:02d}:{:02d}'.format(e // 3600, (e % 3600 // 60), e % 60))
        print('.',end='')
        i += 1
        time.sleep(0.5)
    
    vi_dfs = result.get()
    
    df = pd.concat(vi_dfs, axis=0).reset_index()
    
    if dataset=='train':
        df = df.join(shp_df[['y']], on='farm_id')
        
    df.time = pd.to_datetime(df.time)
    
    # Sort each farm by time
    df = df.sort_values(by=['farm_id','time'])
    
    # After sorting the index will be jumbled, lets throw that away
    df.reset_index(drop=True, inplace=True)
    
    return df

# %%
# %%time
print('-'*50,'Train','-'*50)

train_features_df = create_features_dataset_multi(
    dataset='train',
    agg_methods=['mean','median','std','min','max']
)
# Out:
# -------------------------------------------------- Train --------------------------------------------------
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1503: RuntimeWarning: invalid value encountered in subtract
#   np.subtract(arr, avg, out=arr, casting='unsafe')
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1503: RuntimeWarning: invalid value encountered in subtract
#   np.subtract(arr, avg, out=arr, casting='unsafe')
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1503: RuntimeWarning: invalid value encountered in subtract
#   np.subtract(arr, avg, out=arr, casting='unsafe')
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1503: RuntimeWarning: invalid value encountered in subtract
#   np.subtract(arr, avg, out=arr, casting='unsafe')
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1503: RuntimeWarning: invalid value encountered in subtract
#   np.subtract(arr, avg, out=arr, casting='unsafe')
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1503: RuntimeWarning: invalid value encountered in subtract
#   np.subtract(arr, avg, out=arr, casting='unsafe')
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1503: RuntimeWarning: invalid value encountered in subtract
#   np.subtract(arr, avg, out=arr, casting='unsafe')
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1503: RuntimeWarning: invalid value encountered in subtract
#   np.subtract(arr, avg, out=arr, casting='unsafe')
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1503: RuntimeWarning: invalid value encountered in subtract
#   np.subtract(arr, avg, out=arr, casting='unsafe')
# .
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1503: RuntimeWarning: invalid value encountered in subtract
#   np.subtract(arr, avg, out=arr, casting='unsafe')
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:48: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:48: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:85: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:85: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:85: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:85: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:85: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:85: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:85: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:42: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:42: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:42: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:85: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:85: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:42: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:42: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:85: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:42: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:42: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:42: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:42: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:71: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:71: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:71: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:42: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:96: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:96: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:96: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:71: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:71: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:71: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:71: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:71: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:107: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:71: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:107: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:96: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:96: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:96: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:96: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:96: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:71: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:107: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:96: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:107: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:107: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:107: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:107: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:96: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:107: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:107: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:107: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:48: RuntimeWarning: divide by zero encountered in true_divide
# .
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:48: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:48: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:48: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:48: RuntimeWarning: divide by zero encountered in true_divide
# .
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:48: RuntimeWarning: divide by zero encountered in true_divide
# ......
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:48: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:48: RuntimeWarning: divide by zero encountered in true_divide
# .
#  Elapsed: 00:00:05
# .......
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:42: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:71: RuntimeWarning: divide by zero encountered in true_divide
# .
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-8:
# Process ForkPoolWorker-9:
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-10:
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-1:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# Traceback (most recent call last):
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-3-1cf828709e16>", line 76, in f
#     vi_data = [calc_vi_ts(farm_data, farm_id, agg_methods, vi_method) for vi_method in vi_methods]
#   File "<ipython-input-3-1cf828709e16>", line 76, in f
#     vi_data = [calc_vi_ts(farm_data, farm_id, agg_methods, vi_method) for vi_method in vi_methods]
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-3-1cf828709e16>", line 76, in f
#     vi_data = [calc_vi_ts(farm_data, farm_id, agg_methods, vi_method) for vi_method in vi_methods]
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# Traceback (most recent call last):
#   File "<ipython-input-3-1cf828709e16>", line 76, in <listcomp>
#     vi_data = [calc_vi_ts(farm_data, farm_id, agg_methods, vi_method) for vi_method in vi_methods]
#   File "<ipython-input-3-1cf828709e16>", line 74, in f
#     farm_data = load_for_id(farm_id, dataset, bands_subset=bands_subset)
#   File "<ipython-input-3-1cf828709e16>", line 76, in <listcomp>
#     vi_data = [calc_vi_ts(farm_data, farm_id, agg_methods, vi_method) for vi_method in vi_methods]
#   File "<ipython-input-3-1cf828709e16>", line 74, in f
#     farm_data = load_for_id(farm_id, dataset, bands_subset=bands_subset)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-3-1cf828709e16>", line 76, in f
#     vi_data = [calc_vi_ts(farm_data, farm_id, agg_methods, vi_method) for vi_method in vi_methods]
#   File "<ipython-input-3-1cf828709e16>", line 76, in <listcomp>
#     vi_data = [calc_vi_ts(farm_data, farm_id, agg_methods, vi_method) for vi_method in vi_methods]
#   File "<ipython-input-3-1cf828709e16>", line 61, in calc_vi_ts
#     vi_data[date] = [agg_arr(eval(f'calc_{which_vi}')(bands_data), agg_method) for agg_method in agg_methods]
#   File "<ipython-input-3-1cf828709e16>", line 61, in calc_vi_ts
#     vi_data[date] = [agg_arr(eval(f'calc_{which_vi}')(bands_data), agg_method) for agg_method in agg_methods]
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "<ipython-input-3-1cf828709e16>", line 42, in load_for_id
#     arr = np.load(band_path)
#   File "<ipython-input-3-1cf828709e16>", line 42, in load_for_id
#     arr = np.load(band_path)
#   File "<ipython-input-3-1cf828709e16>", line 74, in f
#     farm_data = load_for_id(farm_id, dataset, bands_subset=bands_subset)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-3-1cf828709e16>", line 68, in calc_vi_ts
#     return pd.concat([vi], keys=[farm_id], names=['farm_id'])
#   File "<ipython-input-3-1cf828709e16>", line 76, in <listcomp>
#     vi_data = [calc_vi_ts(farm_data, farm_id, agg_methods, vi_method) for vi_method in vi_methods]
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/npyio.py", line 430, in load
#     magic = fid.read(N)
#   File "<ipython-input-3-1cf828709e16>", line 61, in <listcomp>
#     vi_data[date] = [agg_arr(eval(f'calc_{which_vi}')(bands_data), agg_method) for agg_method in agg_methods]
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/npyio.py", line 430, in load
#     magic = fid.read(N)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-3-1cf828709e16>", line 61, in <listcomp>
#     vi_data[date] = [agg_arr(eval(f'calc_{which_vi}')(bands_data), agg_method) for agg_method in agg_methods]
#   File "<ipython-input-3-1cf828709e16>", line 42, in load_for_id
#     arr = np.load(band_path)
#   File "<ipython-input-3-1cf828709e16>", line 61, in calc_vi_ts
#     vi_data[date] = [agg_arr(eval(f'calc_{which_vi}')(bands_data), agg_method) for agg_method in agg_methods]
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/pandas/core/reshape/concat.py", line 228, in concat
#     copy=copy, sort=sort)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-3-1cf828709e16>", line 52, in agg_arr
#     return eval(f'np.nan{agg_method}')(arr.flatten())
# KeyboardInterrupt
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/pandas/core/reshape/concat.py", line 381, in __init__
#     self.new_axes = self._get_new_axes()
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/npyio.py", line 447, in load
#     pickle_kwargs=pickle_kwargs)
#   File "<ipython-input-3-1cf828709e16>", line 61, in <listcomp>
#     vi_data[date] = [agg_arr(eval(f'calc_{which_vi}')(bands_data), agg_method) for agg_method in agg_methods]
#   File "<ipython-input-3-1cf828709e16>", line 76, in f
#     vi_data = [calc_vi_ts(farm_data, farm_id, agg_methods, vi_method) for vi_method in vi_methods]
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/nanfunctions.py", line 1628, in nanstd
#     keepdims=keepdims)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/format.py", line 686, in read_array
#     shape, fortran_order, dtype = _read_array_header(fp, version)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/pandas/core/reshape/concat.py", line 461, in _get_new_axes
#     new_axes[self.axis] = self._get_concat_axis()
#   File "<ipython-input-3-1cf828709e16>", line 52, in agg_arr
#     return eval(f'np.nan{agg_method}')(arr.flatten())
#   File "<ipython-input-3-1cf828709e16>", line 76, in f
#     vi_data = [calc_vi_ts(farm_data, farm_id, agg_methods, vi_method) for vi_method in vi_methods]
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/nanfunctions.py", line 1476, in nanvar
#     arr, mask = _replace_nan(a, 0)
#   File "<ipython-input-3-1cf828709e16>", line 76, in <listcomp>
#     vi_data = [calc_vi_ts(farm_data, farm_id, agg_methods, vi_method) for vi_method in vi_methods]
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/format.py", line 560, in _read_array_header
#     not numpy.all([isinstance(x, (int, long)) for x in d['shape']])):
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/pandas/core/reshape/concat.py", line 517, in _get_concat_axis
#     self.levels, self.names)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/nanfunctions.py", line 1079, in nanmedian
#     overwrite_input=overwrite_input)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/nanfunctions.py", line 76, in _replace_nan
#     elif issubclass(a.dtype.type, np.inexact):
#   File "<ipython-input-3-1cf828709e16>", line 76, in <listcomp>
#     vi_data = [calc_vi_ts(farm_data, farm_id, agg_methods, vi_method) for vi_method in vi_methods]
#   File "<ipython-input-3-1cf828709e16>", line 63, in calc_vi_ts
#     vi = pd.DataFrame.from_dict(vi_data, orient='index')
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/core/fromnumeric.py", line 2245, in all
#     return _wrapreduction(a, np.logical_and, 'all', axis, None, out, keepdims=keepdims)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/pandas/core/reshape/concat.py", line 629, in _make_concat_multiindex
#     new_codes.append(np.tile(np.arange(n), kpieces))
# KeyboardInterrupt
#   File "<ipython-input-3-1cf828709e16>", line 63, in calc_vi_ts
#     vi = pd.DataFrame.from_dict(vi_data, orient='index')
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/function_base.py", line 3405, in _ureduce
#     r = func(a, **kwargs)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/pandas/core/frame.py", line 1138, in from_dict
#     return cls(data, index=index, columns=columns, dtype=dtype)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/core/fromnumeric.py", line 86, in _wrapreduction
#     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# KeyboardInterrupt
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/pandas/core/frame.py", line 1138, in from_dict
#     return cls(data, index=index, columns=columns, dtype=dtype)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/nanfunctions.py", line 949, in _nanmedian
#     return _nanmedian1d(part, overwrite_input)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/pandas/core/frame.py", line 448, in __init__
#     dtype=dtype)
# KeyboardInterrupt
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/pandas/core/frame.py", line 448, in __init__
#     dtype=dtype)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/nanfunctions.py", line 936, in _nanmedian1d
#     return np.median(arr1d, overwrite_input=overwrite_input)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/pandas/core/internals/construction.py", line 61, in arrays_to_mgr
#     return create_block_manager_from_arrays(arrays, arr_names, axes)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/pandas/core/internals/construction.py", line 61, in arrays_to_mgr
#     return create_block_manager_from_arrays(arrays, arr_names, axes)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/function_base.py", line 3497, in median
#     overwrite_input=overwrite_input)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/pandas/core/internals/managers.py", line 1666, in create_block_manager_from_arrays
#     blocks = form_blocks(arrays, names, axes)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/pandas/core/internals/managers.py", line 1666, in create_block_manager_from_arrays
#     blocks = form_blocks(arrays, names, axes)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/function_base.py", line 3405, in _ureduce
#     r = func(a, **kwargs)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/pandas/core/internals/managers.py", line 1714, in form_blocks
#     k = names[name_idx]
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/function_base.py", line 3525, in _median
#     part.partition(kth)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/pandas/core/internals/managers.py", line 1722, in form_blocks
#     float_blocks = _multi_blockify(items_dict['FloatBlock'])
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/pandas/core/internals/managers.py", line 1821, in _multi_blockify
#     block = make_block(values, placement=placement)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/pandas/core/indexes/range.py", line 527, in __getitem__
#     if not lib.is_integer(key):
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/pandas/core/internals/blocks.py", line 3088, in make_block
#     klass = get_block_type(values, dtype)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/pandas/core/internals/blocks.py", line 3060, in get_block_type
#     elif is_interval_dtype(dtype) or is_period_dtype(dtype):
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/pandas/core/dtypes/common.py", line 536, in is_interval_dtype
#     def is_interval_dtype(arr_or_dtype):
# KeyboardInterrupt
# Process ForkPoolWorker-7:
# Traceback (most recent call last):
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-3-1cf828709e16>", line 74, in f
#     farm_data = load_for_id(farm_id, dataset, bands_subset=bands_subset)
#   File "<ipython-input-3-1cf828709e16>", line 42, in load_for_id
#     arr = np.load(band_path)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/npyio.py", line 447, in load
#     pickle_kwargs=pickle_kwargs)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/format.py", line 686, in read_array
#     shape, fortran_order, dtype = _read_array_header(fp, version)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/format.py", line 544, in _read_array_header
#     header = _filter_header(header)
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/format.py", line 506, in _filter_header
#     for token in tokenize.generate_tokens(StringIO(string).readline):
#   File "/Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/tokenize.py", line 665, in _tokenize
#     for indent in indents[1:]:                 # pop remaining indent levels
# KeyboardInterrupt
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1503: RuntimeWarning: invalid value encountered in subtract
#   np.subtract(arr, avg, out=arr, casting='unsafe')
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1503: RuntimeWarning: invalid value encountered in subtract
#   np.subtract(arr, avg, out=arr, casting='unsafe')
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1503: RuntimeWarning: invalid value encountered in subtract
#   np.subtract(arr, avg, out=arr, casting='unsafe')
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1503: RuntimeWarning: invalid value encountered in subtract
#   np.subtract(arr, avg, out=arr, casting='unsafe')
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1503: RuntimeWarning: invalid value encountered in subtract
#   np.subtract(arr, avg, out=arr, casting='unsafe')
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1503: RuntimeWarning: invalid value encountered in subtract
#   np.subtract(arr, avg, out=arr, casting='unsafe')
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:48: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:85: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:85: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:85: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:85: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:85: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:85: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:42: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:42: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:42: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:42: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:42: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:42: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:71: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:71: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:71: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:71: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:71: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:71: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:96: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:96: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:96: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:96: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:96: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:96: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:107: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:107: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:107: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:107: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:107: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:107: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1503: RuntimeWarning: invalid value encountered in subtract
#   np.subtract(arr, avg, out=arr, casting='unsafe')
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1503: RuntimeWarning: invalid value encountered in subtract
#   np.subtract(arr, avg, out=arr, casting='unsafe')
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1503: RuntimeWarning: invalid value encountered in subtract
#   np.subtract(arr, avg, out=arr, casting='unsafe')
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:85: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:85: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:85: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:42: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:42: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:42: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:85: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:42: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:71: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:71: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:71: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:96: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:96: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:96: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:107: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:71: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:107: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:107: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:96: RuntimeWarning: invalid value encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:107: RuntimeWarning: invalid value encountered in true_divide
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-3-1cf828709e16> in create_features_dataset_multi(dataset, bands_subset, agg_methods, limit_farms, add_bands)
#     107         print('.',end='')
#     108         i += 1
# --> 109         time.sleep(0.5)
#     110
#     111     vi_dfs = result.get()
#
# KeyboardInterrupt:
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:48: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:48: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1503: RuntimeWarning: invalid value encountered in subtract
#   np.subtract(arr, avg, out=arr, casting='unsafe')
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:48: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:48: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:48: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:48: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:48: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:48: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:48: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:42: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:71: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:42: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:71: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:71: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:71: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:42: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:42: RuntimeWarning: divide by zero encountered in true_divide
# /Users/renier.botha/anaconda3/envs/zindi_farmpin/lib/python3.7/site-packages/ipykernel_launcher.py:42: RuntimeWarning: divide by zero encountered in true_divide

# %%
print('\n')
print('-'*50,'Test','-'*50)
test_features_df = create_features_dataset_multi(
    dataset='test', 
    agg_methods=['mean','median', 'std','min','max']
)
# Out:
# -------------------------------------------------- Test --------------------------------------------------
# ..........
#  Elapsed: 00:00:05
# ..........
#  Elapsed: 00:00:10
# ..........
#  Elapsed: 00:00:15
# ..........
#  Elapsed: 00:00:20
# ..........
#  Elapsed: 00:00:25
# ..........
#  Elapsed: 00:00:30
# ..........
#  Elapsed: 00:00:35
# ..........
#  Elapsed: 00:00:40
# ....

# %% [markdown]
# ## Save to disk

# %%
from config import processed_data_dir
from src.utils import safe_create_dir

out_dir = processed_data_dir / 'VI_datasets' / dataset_version
safe_create_dir(out_dir)

train_features_df.to_csv(out_dir/'train.csv')
test_features_df.to_csv(out_dir/'test.csv')
