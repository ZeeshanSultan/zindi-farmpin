# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import warnings
warnings.simplefilter('ignore')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Multivariate GRU
#
# **Dataset Version:** `v7.1`

# %%
import numpy as np
import pandas as pd

from tqdm import tqdm
from config import interim_data_dir, raw_data_dir

from src.utils import read_shapefile

# %% [markdown]
# ## Load Dataset

# %%
import numpy as np
import pandas as pd

from tqdm import tqdm
from config import interim_data_dir, raw_data_dir

from src.utils import read_shapefile

from config import processed_data_dir

dataset_version = 'v7.1'

train_features_df = pd.read_csv(processed_data_dir/'VI_datasets'/dataset_version/'train.csv', index_col=0)
test_features_df = pd.read_csv(processed_data_dir/'VI_datasets'/dataset_version/'test.csv', index_col=0)

# This is necessary for some reason
train_features_df.farm_id = train_features_df.farm_id.astype(str)
test_features_df.farm_id = test_features_df.farm_id.astype(str)

class_weight = 1-train_features_df.y.value_counts(normalize=True)

train_features_df.shape, test_features_df.shape
# Out:
# ((30470, 113), (11814, 112))

# %%
def impute_nan_inf(df):
    """
    Impute bad values (nan and inf) using
    the median of that feature on that time stamp
    for all farms
    
    TODO: This can be improved
    """
    
    # replace all nans variants with np.nan
    df = df.replace([np.nan, None, np.inf, -np.inf], np.nan)

    # replace all nans with the median value of all farms on that timestamp
    for ts, ts_df in df.groupby('time'):
        df.loc[ts_df.index] = ts_df.fillna(ts_df.median())
        
    return df
        
train_features_df = impute_nan_inf(train_features_df)
test_features_df = impute_nan_inf(test_features_df)

print(train_features_df.shape)
train_features_df.head()
# Out:
# (30470, 113)
#   farm_id        time  ndvi_mean  ndvi_median  ndvi_min  ndvi_max  ndvi_std  \
# 0       1  2017-01-01   0.671766     0.692653  0.454174  0.745895  0.065668
# 1       1  2017-01-31   0.718396     0.729027  0.586915  0.781602  0.046242
# 2       1  2017-02-10   0.746055     0.755768  0.633239  0.798810  0.038175
# 3       1  2017-03-12   0.668629     0.684211  0.514993  0.765019  0.065733
# 4       1  2017-03-22   0.659258     0.673052  0.511155  0.747845  0.055294
#
#    cvi_mean  cvi_median   cvi_min  ...  band_11_median  band_11_min  \
# 0  2.997923    0.947159  0.001221  ...             0.0          0.0
# 1  2.749293    1.052384  0.047159  ...             0.0          0.0
# 2  3.438654    3.456926  2.854073  ...             0.0          0.0
# 3  2.180335    0.865489  0.003610  ...             0.0          0.0
# 4  2.783775    1.226074  0.010952  ...             0.0          0.0
#
#    band_11_max  band_11_std  band_12_mean  band_12_median  band_12_min  \
# 0       2427.0  1033.316114    496.128571             0.0          0.0
# 1       2315.0  1039.211662    521.650000             0.0          0.0
# 2       2482.0  1155.934793    508.700000             0.0          0.0
# 3       2011.0   938.965428    466.950000             0.0          0.0
# 4       1981.0   911.059519    433.728571             0.0          0.0
#
#    band_12_max  band_12_std         y
# 0       1422.0   526.755647  Vineyard
# 1       1382.0   549.157835  Vineyard
# 2       1282.0   533.618506  Vineyard
# 3       1187.0   490.728297  Vineyard
# 4       1105.0   455.879587  Vineyard
#
# [5 rows x 113 columns]

# %% [markdown]
# ## Normalize Features Dataset
#
# Neural Nets are sensitive to scale, but we want to keep the variance in the features. So we will MinMax scale each feature on a specific time step over all farms.
#
# I.e - the network will see any number of variables at a time, but all of them will be on the same scale (0 - 1) and the variance between farms will be kept the same.

# %%
# Make copies to compare before / after normalization
train_copy = train_features_df.copy()
test_copy = test_features_df.copy()

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

times = train_features_df['time'].unique()
feature_cols = [col for col in test_features_df.columns if col not in ['farm_id','time']]

for ts in times:
    scaler = StandardScaler()
    
    train_ts_df = train_copy[train_copy.time == ts]
    test_ts_df = test_copy[test_copy.time == ts]
    
    train_features_df.loc[train_ts_df.index, feature_cols] = scaler.fit_transform(train_ts_df[feature_cols])
    test_features_df.loc[test_ts_df.index, feature_cols] = scaler.transform(test_ts_df[feature_cols])

# %%
train_features_df['id_group'] = train_features_df.farm_id.apply(lambda x: str(x).split('_')[0])
test_features_df['id_group'] = test_features_df.farm_id.apply(lambda x: str(x).split('_')[0])

# %% [markdown]
# ## Transform Dataset for MVTS Classification

# %%
def transform_dataset(features_df):
    """
    Create a data array in the shape (n_ids, n_time, n_features)
    
    If it is the training set, also return dictionary mapping index
    in dataset to correct label.
    
    """
    
    n_ids = features_df.farm_id.nunique()

    feature_cols = [col for col in features_df.columns if col not in ['farm_id','y','time']]
    
    n_features = len(feature_cols)

    data = np.ndarray((n_ids, 11, n_features))
    
    classes = {} # {index: label}
    group_ids = {} # {group: [indexes of farm ids in group]}
    group_labels = {} # {group: label of group}
    for i, (farm_id, farm_df) in enumerate(features_df.groupby(['farm_id'])):

        data[i,:,:] = farm_df[feature_cols].values
        
        if 'y' in features_df.columns:
            c = farm_df['y'].unique()
            classes[i] = c[0]
            
            group = farm_df.id_group.unique()[0]
            
            if group in group_ids:
                group_ids[group].append(i)
            else:
                group_ids[group] = [i]
            
            group_labels[group] = c[0]
            
            
    return data, group_ids, classes, group_labels

# %%
train_data, train_group_ids, train_labels_dict, train_group_labels = transform_dataset(train_features_df)
test_data, _, _, _ = transform_dataset(test_features_df)

print('Train data:\t\t',train_data.shape)
print('Test data:\t\t',test_data.shape)
# Out:
# Train data:		 (2770, 11, 111)
# Test data:		 (1074, 11, 111)

# %%
train_group_labels
# Out:
# {'1': 'Vineyard',
#  '1000': 'Vineyard',
#  '1002': 'Vineyard',
#  '1003': 'Vineyard',
#  '1004': 'Lucern',
#  '1006': 'Lucern',
#  '1007': 'Lucern',
#  '1008': 'Maize',
#  '1009': 'Grass',
#  '1012': 'Lucern',
#  '1013': 'Lucern',
#  '1016': 'Maize',
#  '1017': 'Vineyard',
#  '1019': 'Vineyard',
#  '102': 'Grass',
#  '1020': 'Maize',
#  '1021': 'Vacant',
#  '1022': 'Vacant',
#  '1023': 'Vineyard',
#  '1024': 'Vineyard',
#  '1025': 'Grass',
#  '1026': 'Lucern',
#  '1027': 'Vineyard',
#  '1028': 'Vineyard',
#  '1029': 'Vineyard',
#  '103': 'Grass',
#  '1033': 'Vineyard',
#  '1035': 'Vineyard',
#  '1036': 'Vineyard',
#  '1037': 'Lucern',
#  '1038': 'Vineyard & Pecan ("Intercrop")',
#  '1039': 'Vineyard & Pecan ("Intercrop")',
#  '104': 'Lucern',
#  '1040': 'Vineyard',
#  '1041': 'Vineyard',
#  '1046': 'Lucern',
#  '1047': 'Lucern',
#  '1049': 'Vineyard',
#  '1050': 'Vacant',
#  '1051': 'Cotton',
#  '1052': 'Cotton',
#  '1053': 'Vineyard',
#  '1054': 'Lucern',
#  '1059': 'Lucern',
#  '106': 'Vacant',
#  '1062': 'Lucern',
#  '1063': 'Vineyard',
#  '1064': 'Vineyard',
#  '1065': 'Vineyard',
#  '1066': 'Vineyard',
#  '1067': 'Vineyard',
#  '1069': 'Vineyard & Pecan ("Intercrop")',
#  '107': 'Vacant',
#  '1071': 'Vineyard',
#  '1072': 'Vineyard',
#  '1073': 'Vineyard',
#  '1074': 'Vineyard',
#  '1075': 'Vineyard',
#  '1076': 'Vineyard',
#  '1077': 'Cotton',
#  '1080': 'Maize',
#  '1081': 'Maize',
#  '1084': 'Maize',
#  '1085': 'Lucern',
#  '1087': 'Vacant',
#  '1088': 'Vacant',
#  '1089': 'Vineyard & Pecan ("Intercrop")',
#  '109': 'Vacant',
#  '1090': 'Vineyard',
#  '1091': 'Vineyard',
#  '1093': 'Vineyard',
#  '1095': 'Vineyard',
#  '1096': 'Vineyard',
#  '1097': 'Vineyard',
#  '1099': 'Vineyard',
#  '11': 'Vineyard',
#  '110': 'Lucern',
#  '1100': 'Vineyard',
#  '1103': 'Vineyard',
#  '1104': 'Vineyard',
#  '1105': 'Vineyard',
#  '1106': 'Vineyard',
#  '1107': 'Maize',
#  '1108': 'Lucern',
#  '111': 'Lucern',
#  '1110': 'Vineyard',
#  '1111': 'Lucern',
#  '1112': 'Lucern',
#  '1113': 'Vineyard',
#  '1114': 'Vineyard',
#  '1116': 'Vineyard',
#  '1117': 'Vineyard',
#  '1119': 'Vineyard',
#  '112': 'Lucern',
#  '1120': 'Vineyard',
#  '1121': 'Vineyard',
#  '1122': 'Vineyard',
#  '1123': 'Vineyard',
#  '1124': 'Vineyard & Pecan ("Intercrop")',
#  '1126': 'Maize',
#  '1127': 'Vineyard',
#  '1128': 'Vineyard',
#  '1131': 'Vacant',
#  '1132': 'Lucern',
#  '1134': 'Lucern',
#  '1135': 'Lucern',
#  '1136': 'Lucern',
#  '1137': 'Grass',
#  '1139': 'Vineyard',
#  '114': 'Lucern',
#  '1140': 'Lucern',
#  '1141': 'Lucern',
#  '1142': 'Lucern',
#  '1143': 'Vineyard',
#  '1144': 'Lucern',
#  '1146': 'Vineyard',
#  '1147': 'Vacant',
#  '1148': 'Vineyard',
#  '1149': 'Vineyard',
#  '1150': 'Lucern',
#  '1151': 'Vineyard',
#  '1152': 'Vineyard',
#  '1153': 'Grass',
#  '1154': 'Vineyard',
#  '1155': 'Vineyard',
#  '1157': 'Vineyard',
#  '116': 'Lucern',
#  '1160': 'Vineyard',
#  '1161': 'Vineyard',
#  '1162': 'Vineyard',
#  '1165': 'Vineyard',
#  '117': 'Lucern',
#  '1172': 'Vineyard',
#  '1176': 'Vineyard',
#  '1177': 'Vineyard',
#  '1178': 'Vacant',
#  '1179': 'Vacant',
#  '1180': 'Lucern',
#  '1183': 'Vineyard',
#  '1184': 'Lucern',
#  '1185': 'Vacant',
#  '1186': 'Vacant',
#  '1189': 'Vacant',
#  '119': 'Vineyard',
#  '1191': 'Vineyard',
#  '1192': 'Vineyard',
#  '1193': 'Grass',
#  '1197': 'Grass',
#  '1199': 'Grass',
#  '12': 'Vineyard',
#  '1200': 'Lucern',
#  '1201': 'Lucern',
#  '1203': 'Vineyard',
#  '1204': 'Lucern',
#  '1205': 'Lucern',
#  '1207': 'Maize',
#  '1208': 'Maize',
#  '1209': 'Grass',
#  '1211': 'Vineyard',
#  '1212': 'Grass',
#  '1213': 'Grass',
#  '1214': 'Lucern',
#  '1217': 'Vineyard',
#  '1218': 'Vineyard & Pecan ("Intercrop")',
#  '1219': 'Vineyard',
#  '122': 'Vineyard',
#  '1220': 'Lucern',
#  '1221': 'Lucern',
#  '1222': 'Lucern',
#  '1224': 'Lucern',
#  '1225': 'Maize',
#  '1226': 'Maize',
#  '1227': 'Maize',
#  '1229': 'Vineyard',
#  '1232': 'Vineyard',
#  '1233': 'Maize',
#  '1234': 'Maize',
#  '1236': 'Maize',
#  '1237': 'Vineyard',
#  '1238': 'Lucern',
#  '1239': 'Lucern',
#  '124': 'Lucern',
#  '1241': 'Lucern',
#  '1243': 'Lucern',
#  '1244': 'Lucern',
#  '1245': 'Lucern',
#  '1246': 'Lucern',
#  '1247': 'Lucern',
#  '1248': 'Lucern',
#  '1249': 'Lucern',
#  '1251': 'Lucern',
#  '1252': 'Lucern',
#  '1253': 'Vineyard',
#  '1254': 'Lucern',
#  '1255': 'Lucern',
#  '1258': 'Cotton',
#  '1259': 'Cotton',
#  '1260': 'Cotton',
#  '1261': 'Cotton',
#  '1263': 'Lucern',
#  '1265': 'Lucern',
#  '1266': 'Grass',
#  '1268': 'Grass',
#  '127': 'Vineyard',
#  '1270': 'Lucern',
#  '1271': 'Vacant',
#  '1272': 'Vacant',
#  '1273': 'Grass',
#  '1274': 'Grass',
#  '1276': 'Lucern',
#  '1277': 'Lucern',
#  '1278': 'Vacant',
#  '128': 'Vineyard',
#  '1280': 'Vineyard',
#  '1286': 'Vineyard',
#  '1288': 'Vineyard',
#  '1289': 'Vineyard',
#  '129': 'Vineyard',
#  '1290': 'Vineyard',
#  '1291': 'Vineyard',
#  '1295': 'Lucern',
#  '1297': 'Vineyard',
#  '1298': 'Vineyard',
#  '13': 'Vineyard',
#  '130': 'Vineyard',
#  '1300': 'Lucern',
#  '1303': 'Vineyard',
#  '1304': 'Vineyard',
#  '1305': 'Lucern',
#  '1307': 'Grass',
#  '131': 'Maize',
#  '1310': 'Vineyard',
#  '1313': 'Maize',
#  '1314': 'Vineyard',
#  '1315': 'Vineyard',
#  '1316': 'Vineyard',
#  '1317': 'Vineyard',
#  '1319': 'Grass',
#  '1320': 'Cotton',
#  '1321': 'Cotton',
#  '1322': 'Vineyard',
#  '1323': 'Vineyard',
#  '1324': 'Vineyard',
#  '1326': 'Vineyard',
#  '1327': 'Grass',
#  '1328': 'Grass',
#  '1329': 'Vacant',
#  '1331': 'Maize',
#  '1332': 'Grass',
#  '1333': 'Maize',
#  '1334': 'Grass',
#  '1335': 'Grass',
#  '1336': 'Vineyard',
#  '1337': 'Vacant',
#  '1338': 'Vineyard',
#  '1339': 'Vineyard & Pecan ("Intercrop")',
#  '134': 'Maize',
#  '1340': 'Maize',
#  '1341': 'Grass',
#  '1342': 'Maize',
#  '1343': 'Maize',
#  '1344': 'Grass',
#  '1345': 'Grass',
#  '1346': 'Vineyard',
#  '1347': 'Vineyard',
#  '1348': 'Vineyard',
#  '1349': 'Vacant',
#  '1350': 'Lucern',
#  '1351': 'Vacant',
#  '1352': 'Lucern',
#  '1354': 'Vineyard',
#  '1359': 'Lucern',
#  '136': 'Vacant',
#  '1361': 'Lucern',
#  '1362': 'Lucern',
#  '1363': 'Lucern',
#  '1365': 'Lucern',
#  '1367': 'Vacant',
#  '1368': 'Lucern',
#  '1369': 'Maize',
#  '137': 'Vacant',
#  '1370': 'Maize',
#  '1371': 'Lucern',
#  '1373': 'Lucern',
#  '1374': 'Vineyard',
#  '1375': 'Dates',
#  '1376': 'Vacant',
#  '1378': 'Vineyard',
#  '1379': 'Vineyard',
#  '138': 'Grass',
#  '1380': 'Grass',
#  '1382': 'Dates',
#  '1383': 'Grass',
#  '1384': 'Grass',
#  '1385': 'Vineyard',
#  '1386': 'Vineyard',
#  '1387': 'Grass',
#  '139': 'Maize',
#  '1390': 'Vineyard',
#  '1392': 'Vineyard',
#  '1393': 'Vineyard',
#  '1394': 'Vineyard',
#  '1396': 'Vineyard',
#  '1397': 'Vacant',
#  '1398': 'Vacant',
#  '1399': 'Vineyard',
#  '14': 'Vacant',
#  '140': 'Vacant',
#  '1400': 'Vineyard',
#  '1401': 'Vineyard & Pecan ("Intercrop")',
#  '1404': 'Vacant',
#  '1406': 'Vineyard',
#  '1407': 'Grass',
#  '1409': 'Vineyard',
#  '141': 'Lucern',
#  '1410': 'Vineyard',
#  '1411': 'Vineyard',
#  '1412': 'Vineyard',
#  '1415': 'Vineyard',
#  '1416': 'Vineyard',
#  '1417': 'Vineyard',
#  '1418': 'Vacant',
#  '1419': 'Maize',
#  '142': 'Maize',
#  '1420': 'Vineyard',
#  '1421': 'Maize',
#  '1422': 'Maize',
#  '1423': 'Vineyard',
#  '1424': 'Vineyard',
#  '1425': 'Vacant',
#  '1426': 'Maize',
#  '1428': 'Vineyard',
#  '1429': 'Vineyard',
#  '143': 'Lucern',
#  '1434': 'Vacant',
#  '1435': 'Vacant',
#  '1436': 'Cotton',
#  '1437': 'Cotton',
#  '1438': 'Cotton',
#  '1439': 'Maize',
#  '144': 'Vacant',
#  '1440': 'Vacant',
#  '1441': 'Vacant',
#  '1442': 'Vacant',
#  '1444': 'Vineyard',
#  '1446': 'Grass',
#  '1447': 'Grass',
#  '1448': 'Grass',
#  '1449': 'Grass',
#  '145': 'Lucern',
#  '1451': 'Lucern',
#  '1452': 'Cotton',
#  '1453': 'Maize',
#  '1454': 'Vineyard',
#  '1455': 'Vineyard',
#  '1456': 'Vacant',
#  '1459': 'Vacant',
#  '146': 'Grass',
#  '1461': 'Vineyard & Pecan ("Intercrop")',
#  '1463': 'Lucern',
#  '1464': 'Maize',
#  '1465': 'Lucern',
#  '1466': 'Lucern',
#  '1468': 'Lucern',
#  '1469': 'Lucern',
#  '147': 'Vacant',
#  '1470': 'Lucern',
#  '1472': 'Lucern',
#  '1473': 'Maize',
#  '1474': 'Lucern',
#  '1475': 'Lucern',
#  '1476': 'Vineyard',
#  '1477': 'Vacant',
#  '1479': 'Grass',
#  '148': 'Vacant',
#  '1480': 'Grass',
#  '1481': 'Vacant',
#  '1482': 'Vacant',
#  '1483': 'Vineyard',
#  '1486': 'Vacant',
#  '1487': 'Vacant',
#  '1488': 'Vacant',
#  '1489': 'Vacant',
#  '1490': 'Cotton',
#  '1491': 'Lucern',
#  '1492': 'Cotton',
#  '1494': 'Lucern',
#  '1495': 'Cotton',
#  '1496': 'Cotton',
#  '1498': 'Lucern',
#  '15': 'Vineyard & Pecan ("Intercrop")',
#  '150': 'Vineyard',
#  '1500': 'Vineyard',
#  '1502': 'Vineyard',
#  '1503': 'Vacant',
#  '1504': 'Vineyard',
#  '1505': 'Vineyard',
#  '1507': 'Vineyard',
#  '1508': 'Vineyard & Pecan ("Intercrop")',
#  '1509': 'Vacant',
#  '151': 'Vacant',
#  '1510': 'Lucern',
#  '1511': 'Cotton',
#  '1512': 'Vineyard',
#  '1513': 'Vineyard',
#  '1514': 'Cotton',
#  '1515': 'Lucern',
#  '1516': 'Cotton',
#  '1517': 'Cotton',
#  '1518': 'Cotton',
#  '1519': 'Vineyard',
#  '152': 'Vineyard',
#  '1521': 'Cotton',
#  '1522': 'Cotton',
#  '1523': 'Cotton',
#  '1525': 'Lucern',
#  '1526': 'Vineyard',
#  '1527': 'Lucern',
#  '153': 'Vineyard',
#  '1531': 'Cotton',
#  '1532': 'Vineyard',
#  '1533': 'Vineyard',
#  '1534': 'Vineyard',
#  '1535': 'Vineyard',
#  '1538': 'Cotton',
#  '1539': 'Vineyard',
#  '154': 'Vineyard',
#  '1540': 'Maize',
#  '1541': 'Maize',
#  '1542': 'Vineyard',
#  '1543': 'Cotton',
#  '1544': 'Vineyard',
#  '1545': 'Cotton',
#  '1547': 'Vineyard',
#  '1548': 'Cotton',
#  '1550': 'Cotton',
#  '1551': 'Vineyard',
#  '1552': 'Vacant',
#  '1555': 'Vineyard',
#  '1557': 'Grass',
#  '1558': 'Lucern',
#  '1560': 'Cotton',
#  '1561': 'Cotton',
#  '1562': 'Maize',
#  '1565': 'Vacant',
#  '1568': 'Maize',
#  '157': 'Vineyard',
#  '1570': 'Maize',
#  '1572': 'Maize',
#  '1574': 'Vacant',
#  '1575': 'Vineyard',
#  '1576': 'Vacant',
#  '1577': 'Vineyard',
#  '1579': 'Vineyard',
#  '1580': 'Vineyard',
#  '1581': 'Grass',
#  '1582': 'Vineyard',
#  '1583': 'Vineyard',
#  '1585': 'Cotton',
#  '1586': 'Cotton',
#  '1587': 'Cotton',
#  '1588': 'Vineyard',
#  '1589': 'Cotton',
#  '1590': 'Cotton',
#  '1591': 'Vacant',
#  '1593': 'Vacant',
#  '1596': 'Vineyard',
#  '1597': 'Maize',
#  '1599': 'Vineyard',
#  '16': 'Vineyard & Pecan ("Intercrop")',
#  '1601': 'Lucern',
#  '1602': 'Lucern',
#  '1603': 'Vineyard',
#  '1604': 'Vineyard & Pecan ("Intercrop")',
#  '1605': 'Vineyard',
#  '1606': 'Vineyard',
#  '1607': 'Vineyard',
#  '161': 'Grass',
#  '1610': 'Vineyard',
#  '1611': 'Vineyard',
#  '1613': 'Vineyard',
#  '1614': 'Vineyard & Pecan ("Intercrop")',
#  '1616': 'Lucern',
#  '1617': 'Lucern',
#  '162': 'Lucern',
#  '1620': 'Vineyard',
#  '1621': 'Vineyard',
#  '1622': 'Vineyard',
#  '1623': 'Maize',
#  '1624': 'Lucern',
#  '1626': 'Lucern',
#  '1628': 'Lucern',
#  '1629': 'Vineyard',
#  '163': 'Lucern',
#  '1630': 'Maize',
#  '1631': 'Vineyard',
#  '1632': 'Lucern',
#  '1634': 'Lucern',
#  '1635': 'Vineyard',
#  '1636': 'Vineyard',
#  '1639': 'Vineyard',
#  '164': 'Lucern',
#  '1640': 'Vacant',
#  '1641': 'Vacant',
#  '1643': 'Lucern',
#  '1644': 'Lucern',
#  '1645': 'Lucern',
#  '1647': 'Lucern',
#  '1648': 'Lucern',
#  '165': 'Lucern',
#  '1650': 'Grass',
#  '1651': 'Grass',
#  '1652': 'Grass',
#  '1653': 'Vineyard',
#  '1655': 'Vacant',
#  '1656': 'Vacant',
#  '1658': 'Vacant',
#  '166': 'Vineyard',
#  '1661': 'Vacant',
#  '1662': 'Cotton',
#  '1663': 'Cotton',
#  '1664': 'Cotton',
#  '1669': 'Vineyard',
#  '1670': 'Vineyard',
#  '1671': 'Grass',
#  '1673': 'Cotton',
#  '1676': 'Vineyard',
#  '1677': 'Vineyard',
#  '1679': 'Vineyard',
#  '168': 'Lucern',
#  '1680': 'Vineyard & Pecan ("Intercrop")',
#  '1681': 'Vineyard',
#  '1683': 'Vineyard & Pecan ("Intercrop")',
#  '1687': 'Vineyard',
#  '1688': 'Vacant',
#  '1689': 'Vineyard',
#  '1691': 'Vineyard',
#  '1693': 'Vineyard',
#  '1694': 'Lucern',
#  '1697': 'Vineyard',
#  '1698': 'Vineyard',
#  '1699': 'Vineyard',
#  '17': 'Cotton',
#  '170': 'Maize',
#  '1703': 'Vineyard',
#  '1704': 'Vineyard',
#  '1707': 'Vineyard',
#  '1708': 'Vineyard',
#  '1709': 'Maize',
#  '171': 'Maize',
#  '1712': 'Lucern',
#  '1713': 'Vineyard',
#  '1714': 'Lucern',
#  '1716': 'Lucern',
#  '1717': 'Vacant',
#  '1718': 'Vacant',
#  '1719': 'Vacant',
#  '1722': 'Lucern',
#  '1723': 'Lucern',
#  '1726': 'Lucern',
#  '1727': 'Maize',
#  '1728': 'Vacant',
#  '173': 'Grass',
#  '1730': 'Vacant',
#  '1731': 'Vineyard',
#  '1733': 'Vineyard',
#  '1734': 'Vineyard',
#  '1736': 'Lucern',
#  '1737': 'Cotton',
#  '1738': 'Cotton',
#  '174': 'Vacant',
#  '1741': 'Cotton',
#  '1742': 'Cotton',
#  '1743': 'Cotton',
#  '1744': 'Cotton',
#  '1745': 'Vineyard',
#  '1746': 'Cotton',
#  '1747': 'Cotton',
#  '1749': 'Cotton',
#  '175': 'Vacant',
#  '1750': 'Cotton',
#  '1751': 'Cotton',
#  '1755': 'Maize',
#  '1756': 'Lucern',
#  '1757': 'Lucern',
#  '1758': 'Cotton',
#  '1759': 'Cotton',
#  '1763': 'Maize',
#  '1764': 'Grass',
#  '1765': 'Grass',
#  '1766': 'Maize',
#  '1767': 'Maize',
#  '1769': 'Vineyard',
#  '1770': 'Vineyard',
#  '1771': 'Vineyard',
#  '1772': 'Lucern',
#  '1775': 'Vineyard',
#  '1776': 'Vineyard',
#  '1777': 'Vineyard',
#  '1778': 'Lucern',
#  '1779': 'Vineyard',
#  '178': 'Vineyard',
#  '1780': 'Maize',
#  '1781': 'Lucern',
#  '1782': 'Vineyard',
#  '1783': 'Maize',
#  '1785': 'Vineyard',
#  '1786': 'Dates',
#  '1787': 'Vineyard',
#  '1788': 'Maize',
#  '1789': 'Maize',
#  '179': 'Vineyard',
#  '1791': 'Lucern',
#  '1792': 'Vineyard',
#  '1793': 'Vineyard',
#  '1794': 'Vineyard',
#  '1797': 'Lucern',
#  '1798': 'Lucern',
#  '1799': 'Lucern',
#  '180': 'Vineyard',
#  '1803': 'Cotton',
#  '1804': 'Lucern',
#  '1805': 'Lucern',
#  '1807': 'Lucern',
#  '1808': 'Vineyard',
#  '1809': 'Vineyard & Pecan ("Intercrop")',
#  '181': 'Vineyard',
#  '1811': 'Vineyard',
#  '1812': 'Lucern',
#  '1813': 'Vineyard',
#  '1814': 'Vineyard',
#  '1815': 'Lucern',
#  '1816': 'Vineyard',
#  '1819': 'Vineyard',
#  '182': 'Maize',
#  '1823': 'Vineyard',
#  '1825': 'Vineyard',
#  '1827': 'Vineyard',
#  '1828': 'Vineyard',
#  '1829': 'Lucern',
#  '183': 'Cotton',
#  '1831': 'Lucern',
#  '1832': 'Lucern',
#  '1834': 'Vacant',
#  '1835': 'Vacant',
#  '1838': 'Lucern',
#  '1839': 'Vineyard',
#  '184': 'Cotton',
#  '1840': 'Vineyard',
#  '1842': 'Lucern',
#  '1843': 'Vineyard',
#  '1845': 'Lucern',
#  '1846': 'Vineyard',
#  '1849': 'Vineyard',
#  '185': 'Cotton',
#  '1850': 'Lucern',
#  '1853': 'Vineyard',
#  '1854': 'Lucern',
#  '1855': 'Grass',
#  '1856': 'Vacant',
#  '1858': 'Vineyard',
#  '186': 'Grass',
#  '1860': 'Vineyard',
#  '1861': 'Vacant',
#  '1862': 'Vineyard',
#  '1867': 'Vineyard',
#  '1868': 'Vineyard',
#  '1869': 'Vineyard',
#  '1870': 'Lucern',
#  '1871': 'Maize',
#  '1873': 'Lucern',
#  '1875': 'Lucern',
#  '1878': 'Vineyard',
#  '1879': 'Vineyard',
#  '1881': 'Grass',
#  '1882': 'Vineyard',
#  '1883': 'Vineyard',
#  '1884': 'Vineyard',
#  '1886': 'Vineyard',
#  '1887': 'Dates',
#  '1889': 'Vacant',
#  '189': 'Cotton',
#  '1890': 'Maize',
#  '1891': 'Maize',
#  '1893': 'Vacant',
#  '1894': 'Lucern',
#  '1899': 'Vineyard',
#  '19': 'Vineyard',
#  '1900': 'Lucern',
#  '1901': 'Vacant',
#  '1902': 'Vineyard',
#  '1904': 'Vineyard & Pecan ("Intercrop")',
#  '1905': 'Vineyard',
#  '1906': 'Vineyard',
#  '1907': 'Vineyard',
#  '1908': 'Lucern',
#  '191': 'Vacant',
#  '1910': 'Vineyard',
#  '1911': 'Vacant',
#  '1913': 'Vacant',
#  '1915': 'Vacant',
#  '1917': 'Grass',
#  '1919': 'Vineyard',
#  '192': 'Vacant',
#  '1920': 'Vineyard',
#  '1921': 'Vineyard',
#  '1922': 'Vineyard',
#  '1923': 'Vineyard',
#  '1924': 'Vineyard',
#  '1925': 'Vineyard',
#  '1926': 'Vineyard',
#  '1927': 'Vineyard',
#  '1928': 'Vineyard',
#  '1929': 'Vineyard',
#  '193': 'Vacant',
#  '1931': 'Lucern',
#  '1933': 'Vineyard',
#  '1934': 'Vineyard',
#  '1936': 'Vineyard',
#  '1937': 'Vineyard',
#  '1938': 'Lucern',
#  '194': 'Vacant',
#  '1940': 'Vacant',
#  '1942': 'Vineyard',
#  '1944': 'Vacant',
#  '1945': 'Lucern',
#  '1946': 'Vineyard & Pecan ("Intercrop")',
#  '1947': 'Lucern',
#  '1949': 'Vineyard',
#  '195': 'Grass',
#  '1950': 'Vineyard',
#  '1951': 'Vineyard',
#  '1952': 'Maize',
#  '1953': 'Vineyard',
#  '1954': 'Vineyard',
#  '1955': 'Lucern',
#  '1956': 'Vineyard',
#  '1958': 'Vineyard & Pecan ("Intercrop")',
#  '1960': 'Vineyard & Pecan ("Intercrop")',
#  '1961': 'Vineyard',
#  '1963': 'Vineyard',
#  '1964': 'Vineyard',
#  '1967': 'Vacant',
#  '1968': 'Vacant',
#  '1969': 'Vineyard',
#  '1970': 'Vineyard',
#  '1971': 'Vineyard & Pecan ("Intercrop")',
#  '1972': 'Vacant',
#  '1974': 'Maize',
#  '1975': 'Lucern',
#  '1976': 'Vineyard',
#  '1977': 'Maize',
#  '1979': 'Maize',
#  '198': 'Vineyard',
#  '1980': 'Vineyard',
#  '1981': 'Vineyard',
#  '1983': 'Vineyard',
#  '1984': 'Vineyard',
#  '1986': 'Vineyard',
#  '1988': 'Vineyard',
#  '1989': 'Vineyard',
#  '199': 'Vineyard',
#  '1990': 'Vineyard & Pecan ("Intercrop")',
#  '1991': 'Vineyard',
#  '1992': 'Vineyard',
#  '1993': 'Vineyard & Pecan ("Intercrop")',
#  '1994': 'Lucern',
#  '1995': 'Lucern',
#  '1996': 'Vineyard',
#  '1997': 'Vineyard',
#  '1998': 'Vineyard',
#  '2': 'Pecan',
#  '20': 'Vineyard',
#  '200': 'Vineyard',
#  '2000': 'Vineyard',
#  '2001': 'Vineyard & Pecan ("Intercrop")',
#  '2002': 'Vineyard',
#  '2003': 'Vineyard',
#  '2006': 'Vineyard & Pecan ("Intercrop")',
#  '2007': 'Vineyard & Pecan ("Intercrop")',
#  '2008': 'Vineyard & Pecan ("Intercrop")',
#  '2009': 'Vineyard',
#  '2010': 'Vineyard',
#  '2012': 'Vineyard',
#  '2013': 'Vineyard',
#  '2015': 'Vacant',
#  '2016': 'Vineyard',
#  '2017': 'Vacant',
#  '2018': 'Vacant',
#  '2019': 'Vineyard & Pecan ("Intercrop")',
#  '202': 'Maize',
#  '2020': 'Lucern',
#  '2022': 'Vineyard',
#  '2024': 'Vacant',
#  '2025': 'Lucern',
#  '2026': 'Lucern',
#  '2027': 'Maize',
#  '2028': 'Vineyard',
#  '2029': 'Vineyard',
#  '2030': 'Lucern',
#  '2031': 'Vineyard',
#  '2035': 'Vineyard',
#  '2036': 'Vineyard',
#  '2037': 'Vineyard',
#  '2038': 'Vineyard',
#  '2040': 'Vineyard',
#  '2041': 'Vineyard',
#  '2042': 'Vineyard',
#  '2044': 'Maize',
#  '2045': 'Maize',
#  '2046': 'Lucern',
#  '2047': 'Vineyard',
#  '2048': 'Maize',
#  '2049': 'Lucern',
#  '205': 'Maize',
#  '2050': 'Lucern',
#  '2051': 'Lucern',
#  '2054': 'Maize',
#  '2055': 'Vacant',
#  '2057': 'Vineyard',
#  '206': 'Vacant',
#  '2061': 'Vineyard',
#  '2062': 'Vineyard',
#  '2063': 'Vacant',
#  '2064': 'Vineyard',
#  '2066': 'Vineyard',
#  '2068': 'Vacant',
#  '2069': 'Lucern',
#  '2070': 'Lucern',
#  '2072': 'Lucern',
#  '2073': 'Lucern',
#  '2075': 'Cotton',
#  '2076': 'Cotton',
#  '2077': 'Cotton',
#  '2078': 'Lucern',
#  '2079': 'Lucern',
#  '208': 'Lucern',
#  '2081': 'Vacant',
#  '2082': 'Lucern',
#  '2083': 'Lucern',
#  '2084': 'Cotton',
#  '2085': 'Vacant',
#  '209': 'Vacant',
#  '2091': 'Maize',
#  '2093': 'Vacant',
#  '2094': 'Vineyard',
#  '2095': 'Vineyard',
#  '2096': 'Vineyard',
#  '2098': 'Vineyard',
#  '21': 'Vineyard',
#  '210': 'Grass',
#  '2100': 'Lucern',
#  '2101': 'Vineyard',
#  '2103': 'Vineyard',
#  '2104': 'Maize',
#  '2106': 'Lucern',
#  '2107': 'Vacant',
#  '2109': 'Lucern',
#  '2110': 'Lucern',
#  '2112': 'Vineyard',
#  '2115': 'Vineyard',
#  '212': 'Lucern',
#  '2120': 'Vineyard',
#  '2122': 'Vineyard',
#  '2124': 'Vineyard',
#  '2125': 'Vineyard',
#  '2126': 'Lucern',
#  '2127': 'Lucern',
#  '213': 'Vacant',
#  '2130': 'Lucern',
#  '2131': 'Lucern',
#  '2132': 'Lucern',
#  '2134': 'Lucern',
#  '2135': 'Lucern',
#  '2136': 'Lucern',
#  '2137': 'Lucern',
#  '2138': 'Vineyard',
#  '2140': 'Vineyard',
#  '2141': 'Vineyard',
#  '2142': 'Vineyard',
#  '2143': 'Lucern',
#  '2144': 'Vineyard & Pecan ("Intercrop")',
#  '2145': 'Vineyard & Pecan ("Intercrop")',
#  '2146': 'Lucern',
#  '2147': 'Vineyard',
#  '2148': 'Lucern',
#  '2149': 'Vineyard',
#  '2151': 'Lucern',
#  '2152': 'Vacant',
#  '2155': 'Vineyard',
#  '2156': 'Cotton',
#  '2157': 'Lucern',
#  '2158': 'Cotton',
#  '2159': 'Cotton',
#  '216': 'Vacant',
#  '2160': 'Vineyard',
#  '2161': 'Vineyard',
#  '2162': 'Maize',
#  '2163': 'Maize',
#  '2164': 'Lucern',
#  '2165': 'Maize',
#  '2167': 'Lucern',
#  '2168': 'Maize',
#  '2169': 'Maize',
#  '2171': 'Maize',
#  '2174': 'Vineyard & Pecan ("Intercrop")',
#  '2175': 'Vineyard & Pecan ("Intercrop")',
#  '2176': 'Vineyard & Pecan ("Intercrop")',
#  '2177': 'Vineyard & Pecan ("Intercrop")',
#  '2178': 'Vineyard & Pecan ("Intercrop")',
#  '2179': 'Vineyard',
#  '218': 'Lucern',
#  '2180': 'Vineyard & Pecan ("Intercrop")',
#  '2181': 'Lucern',
#  '2182': 'Maize',
#  '2183': 'Vineyard',
#  '2184': 'Vineyard',
#  '2185': 'Lucern',
#  '2186': 'Lucern',
#  '2187': 'Lucern',
#  '2188': 'Lucern',
#  '2190': 'Vineyard',
#  '2191': 'Vineyard',
#  '2192': 'Vineyard',
#  '2193': 'Vineyard',
#  '2194': 'Vacant',
#  '2195': 'Vineyard',
#  '2196': 'Maize',
#  '2197': 'Lucern',
#  '2198': 'Maize',
#  '22': 'Vineyard',
#  '2200': 'Maize',
#  '2201': 'Vacant',
#  '2203': 'Lucern',
#  '2204': 'Lucern',
#  '2205': 'Vineyard',
#  '2208': 'Vacant',
#  '2209': 'Vacant',
#  '221': 'Grass',
#  '2210': 'Vacant',
#  '2213': 'Vineyard',
#  '2214': 'Vineyard',
#  '2216': 'Maize',
#  '2217': 'Vineyard',
#  '2218': 'Lucern',
#  '2220': 'Lucern',
#  '2221': 'Maize',
#  '2222': 'Lucern',
#  '2223': 'Grass',
#  '2226': 'Vineyard',
#  '2227': 'Vineyard',
#  '2228': 'Vacant',
#  '2229': 'Vineyard',
#  '223': 'Grass',
#  '2230': 'Vineyard',
#  '2231': 'Vineyard',
#  '2232': 'Lucern',
#  '2233': 'Vineyard',
#  '2235': 'Lucern',
#  '2236': 'Lucern',
#  '2238': 'Vineyard',
#  '224': 'Grass',
#  '2240': 'Vineyard',
#  '2241': 'Vineyard',
#  '2242': 'Lucern',
#  '2243': 'Lucern',
#  '2245': 'Lucern',
#  '2246': 'Vineyard',
#  '2248': 'Vineyard',
#  '225': 'Lucern',
#  '2253': 'Vineyard',
#  '2255': 'Vineyard',
#  '2256': 'Maize',
#  '2259': 'Vineyard',
#  '226': 'Vacant',
#  '2260': 'Vineyard',
#  '2261': 'Vineyard',
#  '2263': 'Maize',
#  '2264': 'Lucern',
#  '2266': 'Lucern',
#  '2267': 'Maize',
#  '2268': 'Lucern',
#  '2271': 'Lucern',
#  '2274': 'Lucern',
#  '2276': 'Lucern',
#  '2277': 'Lucern',
#  '2278': 'Lucern',
#  '228': 'Vacant',
#  '2281': 'Vineyard',
#  '2283': 'Lucern',
#  '2285': 'Cotton',
#  '2286': 'Lucern',
#  '2287': 'Lucern',
#  '2288': 'Vineyard',
#  '2289': 'Vineyard',
#  '229': 'Vacant',
#  '2292': 'Cotton',
#  '2293': 'Cotton',
#  '2294': 'Vineyard',
#  '2295': 'Vineyard',
#  ...}

# %% [markdown]
# ## Start Modelling Process
#
# ### Create validation set

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

def group_train_test_split( groups, group_labels, test_size, random_seed):
    """
    
    """
    
    pass    

seed = 420

# Copy for later
data = train_data.copy()

x_group_list = list(train_group_labels.keys())
y_group_list = list(train_group_labels.values())

# Split groups into train / val
train_group_list, val_group_list, train_group_y, val_group_y = train_test_split(x_group_list, 
                                                                                y_group_list, 
                                                                                stratify=y_group_list, 
                                                                                test_size=0.2, 
                                                                                random_state=seed)

# %%
x_group_list[:5]
# Out:
# ['1', '1000', '1002', '1003', '1004']

# %%
# Get the index
train_idx = []
train_labels = []
for group, label in zip(train_group_list, train_group_y):
    
    # Get index of all farms in this group
    ids_in_group = train_group_ids[group]
    
    train_idx.extend(ids_in_group)
    train_labels.extend([label]*len(ids_in_group))
    
    
val_idx = []
val_labels = []
for group, label in zip(val_group_list, val_group_y):
    
    # Get index of all farms in this group
    ids_in_group = train_group_ids[group]
                    
    val_idx.extend([ids_in_group[0]])
    val_labels.extend([label])

# %%
le = LabelEncoder()
train_labels_enc = le.fit_transform(np.array(train_labels).reshape(-1,1))
val_labels_enc = le.transform(np.array(val_labels).reshape(-1,1))

train_data = data[train_idx,:, :]
val_data = data[val_idx,:, :]

print('train data : ',train_data.shape)
print('val data : ',val_data.shape)
# Out:
# train data :  (2222, 11, 111)
# val data :  (499, 11, 111)

# %% [markdown]
# ### TODO:
#
# From validation set, delete all upsampled data

# %% [markdown]
# ### Create model

# %%
import tensorflow as tf
import keras
from keras import models, layers
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

from src.visualization.tf_viz import PlotLosses

## Set trainig params
epoch_size=2000
batch_size=64

def get_model(n_features):

    model = models.Sequential()
    model.add(layers.Dense(8, activation='relu', input_shape=(11, n_features)))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.1))
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.1))
    model.add(layers.GRU(8, 
                         input_shape=(11, n_features),
                         kernel_regularizer=keras.regularizers.l2(0.01), 
                         return_sequences=True))
    model.add(layers.GRU(8, 
                         input_shape=(11, n_features), 
                         kernel_regularizer=keras.regularizers.l2(0.01), 
                         return_sequences=True))
    model.add(layers.Flatten())
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(9, activation='softmax'))
    return model

# %%
from src.models.clr_callback import CyclicLR

# Get the model
model = get_model(train_data.shape[-1])

# Choose optimizer
# optimizer = keras.optimizers.RMSprop()
optimizer = keras.optimizers.Adam(3e-4)

# Choose callbacks
plot_losses = PlotLosses()
es = EarlyStopping(monitor='val_loss', verbose=1, patience=120)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', patience=40, verbose=1, factor=0.5, min_delta=0.001,)

callbacks = [
    plot_losses, 
    es, 
    reduce_lr
]

model.compile(optimizer=optimizer,
              loss='sparse_categorical_crossentropy')

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 11, 8)             896
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 11, 8)             32
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 11, 8)             0
# _________________________________________________________________
# dense_17 (Dense)             (None, 11, 64)            576
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 11, 64)            256
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 11, 64)            0
# _________________________________________________________________
# gru_11 (GRU)                 (None, 11, 8)             1752
# _________________________________________________________________
# gru_12 (GRU)                 (None, 11, 8)             408
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 88)                0
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 88)                352
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 88)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 9)                 801
# =================================================================
# Total params: 5,073
# Trainable params: 4,753
# Non-trainable params: 320
# _________________________________________________________________

# %%
model.fit(train_data, 
          train_labels_enc,
          batch_size=batch_size,
          validation_data=(val_data, val_labels_enc), 
#           class_weight=class_weight,
          verbose=0,
          epochs=epoch_size, 
          callbacks=callbacks)
# Out:
# Epoch 00432: ReduceLROnPlateau reducing learning rate to 1.8750000890577212e-05.
# Epoch 00432: early stopping

# %%
from sklearn.metrics import log_loss

val_preds = model.predict(val_data)
train_preds = model.predict(train_data)
print('val loss: ',log_loss(val_labels_enc, val_preds))
print('train loss: ',log_loss(train_labels_enc, train_preds))

# %% [markdown]
# ### Confusion matrix

# %%
from sklearn.metrics import confusion_matrix
from src.visualization.visualize import print_confusion_matrix

class_labels = pd.read_csv(raw_data_dir / 'crop_id_list.csv', index_col=0).sort_index().crop

val_preds = model.predict_classes(val_data)

cm = confusion_matrix(val_labels_enc, val_preds)
print_confusion_matrix(cm, class_names=class_labels);

# %% [markdown]
# ## Make Submission

# %% [markdown]
# ### First retrain on all data

# %%
all_data = np.vstack([train_data, val_data])
all_labels = np.array(list(train_labels_enc) + list(val_labels_enc))

class_weight = (1 - pd.Series(all_labels).value_counts(normalize=True)).to_dict()

# %%
model = get_model(all_data.shape[-1])
optimizer = keras.optimizers.RMSprop(lr)
model.compile(optimizer=optimizer,
              loss=keras.metrics.sparse_categorical_crossentropy,
              metrics=[keras.metrics.sparse_categorical_crossentropy])

model.fit(all_data, 
          all_labels,
          batch_size=64, 
          class_weight=class_weight,
          verbose=2,
          epochs=350, 
          workers=4, 
          use_multiprocessing=True,
          callbacks=[plot_losses, es, reduce_lr])

# %%
def make_sub(predictions, ids_list):
    
    sub_df = pd.read_csv(raw_data_dir / 'sample_submission_fixed.csv')

    new_sub = sub_df.copy().set_index('field_id')

    new_sub.loc[ids_list] = predictions
    
    return new_sub

predictions = model.predict(test_data)
test_ids = sorted(list(test_features_df.farm_id.unique()))
sub_df = make_sub(predictions, test_ids)
sub_df.head()

# %% [markdown]
# ### Save submission file

# %%
from config import subs_dir

sub_df.to_csv(subs_dir / 'gru_vi_data_v4.1.csv')

# %% [markdown]
# ### Save model architecture

# %%
with open(subs_dir / 'architectures')
