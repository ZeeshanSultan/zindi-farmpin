# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# # Create ts_fresh Dataset

# %%
import numpy as np
import pandas as pd

from tqdm import tqdm
from config import interim_data_dir, processed_data_dir

from src.utils import safe_create_dir

dataset_version = 'v1'

input_dir = processed_data_dir / 'VI_datasets' / dataset_version

# %% [markdown]
# ## Load VI Dataset (longform)

# %%
def impute_nan_inf(df):
    """
    Impute bad values (nan and inf) using
    the median of that feature on that time stamp
    for all farms
    
    TODO: This can be improved
    """
    
    # replace all nans variants with np.nan
    df = df.replace([np.nan, None, np.inf, -np.inf], np.nan)

    # replace all nans with the median value of all farms on that timestamp
    for ts, ts_df in df.groupby('time'):
        df.loc[ts_df.index] = ts_df.fillna(ts_df.median())
        
    return df

train_df = pd.read_csv(input_dir/'train.csv', index_col=0)
test_df = pd.read_csv(input_dir/'test.csv', index_col=0)

train_df = impute_nan_inf(train_df)
test_df = impute_nan_inf(test_df)

# %%
train_df.head()
# Out:
#    farm_id        time  ndvi_min  ndvi_mean  ndvi_median  ndvi_std  ndvi_max  \
# 0        1  2017-01-01  0.454174   0.671766     0.692653  0.065668  0.745895
# 1        1  2017-01-31  0.586915   0.718396     0.729027  0.046242  0.781602
# 2        1  2017-02-10  0.633239   0.746055     0.755768  0.038175  0.798810
# 3        1  2017-03-12  0.514993   0.668629     0.684211  0.065733  0.765019
# 4        1  2017-03-22  0.511155   0.659258     0.673052  0.055294  0.747845
#
#     cvi_min  cvi_mean  cvi_median    ...     evi_mean  evi_median   evi_std  \
# 0  0.001221  3.001651    0.947159    ...     2.474928         0.0  2.691551
# 1  0.047159  2.744553    1.052384    ...     2.208423         0.0  2.330548
# 2  0.031403  1.977070    1.065654    ...     2.510243         0.0  2.629651
# 3  0.003610  2.180335    0.865489    ...     3.435664         0.0  3.770609
# 4  0.010952  2.783775    1.226074    ...     4.197762         0.0  4.720135
#
#      evi_max  arvi2_min  arvi2_mean  arvi2_median  arvi2_std  arvi2_max  \
# 0   6.758784   0.351384    0.605966      0.630404   0.076831   0.692697
# 1   5.673348   0.506691    0.660523      0.672961   0.054103   0.734474
# 2   5.792201   0.560890    0.692884      0.704249   0.044665   0.754608
# 3  11.882745   0.422541    0.602296      0.620526   0.076907   0.715073
# 4  14.271617   0.418052    0.591332      0.607470   0.064695   0.694979
#
#           y
# 0  Vineyard
# 1  Vineyard
# 2  Vineyard
# 3  Vineyard
# 4  Vineyard
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Ts-fresh

# %%
from tsfresh import extract_relevant_features, extract_features

# %%
reduced_features_list = ['ndvi','reip','dartt3']
reduced_cols_list = ['farm_id','time'] + list(train_df.columns[train_df.columns.str.contains('|'.join(reduced_features_list))] )

labels = train_df.groupby('farm_id').apply(lambda x: x.y.unique()[0])
labels.name='y'

# %%
train_reduced = train_df[reduced_cols_list]
test_reduced = test_df[reduced_cols_list]

train_fresh = extract_relevant_features(train_reduced, labels, column_id='farm_id', column_sort='time', n_jobs=10)

# %%
train_selected = train_selected.join(labels)

# %%
test_fresh = extract_features(test_reduced, column_id='farm_id', column_sort='time', n_jobs=10)
test_selected = test_fresh[train_selected.columns]
# Out:
# Feature Extraction:   0%|          | 0/50 [00:00<?, ?it/s]
#
# Feature Extraction:   2%|▏         | 1/50 [00:20<16:54, 20.70s/it]
#
# Feature Extraction:   4%|▍         | 2/50 [00:20<11:39, 14.56s/it]
#
# Feature Extraction:   6%|▌         | 3/50 [00:21<08:01, 10.24s/it]
#
# Feature Extraction:   8%|▊         | 4/50 [00:21<05:32,  7.22s/it]
#
# Feature Extraction:  10%|█         | 5/50 [00:21<03:50,  5.12s/it]
#
# Feature Extraction:  12%|█▏        | 6/50 [00:21<02:40,  3.65s/it]
#
# Feature Extraction:  14%|█▍        | 7/50 [00:21<01:52,  2.61s/it]
#
# Feature Extraction:  16%|█▌        | 8/50 [00:22<01:19,  1.89s/it]
#
# Feature Extraction:  18%|█▊        | 9/50 [00:22<00:56,  1.39s/it]
#
# Feature Extraction:  20%|██        | 10/50 [00:22<00:41,  1.05s/it]
#
# Feature Extraction:  22%|██▏       | 11/50 [00:40<03:59,  6.14s/it]
#
# Feature Extraction:  24%|██▍       | 12/50 [00:40<02:47,  4.41s/it]
#
# Feature Extraction:  26%|██▌       | 13/50 [00:41<01:58,  3.20s/it]
#
# Feature Extraction:  28%|██▊       | 14/50 [00:41<01:24,  2.35s/it]
#
# Feature Extraction:  30%|███       | 15/50 [00:42<01:00,  1.73s/it]
#
# Feature Extraction:  32%|███▏      | 16/50 [00:42<00:44,  1.29s/it]
#
# Feature Extraction:  34%|███▍      | 17/50 [00:42<00:31,  1.03it/s]
#
# Feature Extraction:  36%|███▌      | 18/50 [00:44<00:44,  1.40s/it]
#
# Feature Extraction:  38%|███▊      | 19/50 [00:45<00:33,  1.08s/it]
#
# Feature Extraction:  40%|████      | 20/50 [00:45<00:25,  1.18it/s]
#
# Feature Extraction:  42%|████▏     | 21/50 [01:03<02:49,  5.84s/it]
#
# Feature Extraction:  44%|████▍     | 22/50 [01:03<01:58,  4.22s/it]
#
# Feature Extraction:  46%|████▌     | 23/50 [01:04<01:24,  3.14s/it]
#
# Feature Extraction:  48%|████▊     | 24/50 [01:04<01:00,  2.32s/it]
#
# Feature Extraction:  50%|█████     | 25/50 [01:04<00:42,  1.70s/it]
#
# Feature Extraction:  52%|█████▏    | 26/50 [01:04<00:30,  1.27s/it]
#
# Feature Extraction:  54%|█████▍    | 27/50 [01:05<00:22,  1.03it/s]
#
# Feature Extraction:  56%|█████▌    | 28/50 [01:05<00:16,  1.30it/s]
#
# Feature Extraction:  58%|█████▊    | 29/50 [01:06<00:19,  1.05it/s]
#
# Feature Extraction:  60%|██████    | 30/50 [01:07<00:15,  1.32it/s]
#
# Feature Extraction:  62%|██████▏   | 31/50 [01:23<01:41,  5.37s/it]
#
# Feature Extraction:  64%|██████▍   | 32/50 [01:23<01:10,  3.90s/it]
#
# Feature Extraction:  66%|██████▌   | 33/50 [01:24<00:49,  2.94s/it]
#
# Feature Extraction:  68%|██████▊   | 34/50 [01:24<00:34,  2.13s/it]
#
# Feature Extraction:  70%|███████   | 35/50 [01:25<00:23,  1.58s/it]
#
# Feature Extraction:  72%|███████▏  | 36/50 [01:25<00:16,  1.20s/it]
#
# Feature Extraction:  74%|███████▍  | 37/50 [01:25<00:12,  1.06it/s]
#
# Feature Extraction:  76%|███████▌  | 38/50 [01:25<00:08,  1.36it/s]
#
# Feature Extraction:  78%|███████▊  | 39/50 [01:27<00:12,  1.11s/it]
#
# Feature Extraction:  80%|████████  | 40/50 [01:28<00:09,  1.10it/s]
#
# Feature Extraction:  82%|████████▏ | 41/50 [01:46<00:54,  6.01s/it]
#
# Feature Extraction:  84%|████████▍ | 42/50 [01:47<00:37,  4.63s/it]
#
# Feature Extraction:  86%|████████▌ | 43/50 [01:48<00:23,  3.35s/it]
#
# Feature Extraction:  88%|████████▊ | 44/50 [01:48<00:15,  2.53s/it]
#
# Feature Extraction:  90%|█████████ | 45/50 [01:48<00:09,  1.84s/it]
#
# Feature Extraction:  92%|█████████▏| 46/50 [01:49<00:05,  1.35s/it]
#
# Feature Extraction:  94%|█████████▍| 47/50 [01:49<00:03,  1.01s/it]
#
# Feature Extraction:  96%|█████████▌| 48/50 [01:49<00:01,  1.22it/s]
#
# Feature Extraction:  98%|█████████▊| 49/50 [01:50<00:00,  1.42it/s]
#
# Feature Extraction: 100%|██████████| 50/50 [01:50<00:00,  1.66it/s]

# %% [markdown]
# ## Save Dataset

# %%
from src.utils import safe_create_dir

output_dir = processed_data_dir / 'ts_fresh' / dataset_version
safe_create_dir(output_dir)

train_selected.to_csv(output_dir/'train.csv')
test_selected.to_csv(output_dir/'test.csv')
